# %% [markdown]
# ## Data Cleaning
# Para resumir todas las acciones que tenemos que realizar cuando recibimos un dataset en cuestión de limpieza de datos, vamos a utilizar un fichero con la información de los pasajeros del barco Titanic.
#
# Este dataset contiene las siguente información en sus columnas:
#
# * **survival:**  Superviviente (0 = No, 1 = Si)
# * **pclass:**	Clase den el barco	(1 = 1st, 2 = 2nd, 3 = 3rd)
# * **sex:**	Sexo
# * **Age:**	Edad en años
# * **sibsp:**	Número de hermanos
# * **parch:**	Número de hijos
# * **ticket:**	Número del billete
# * **fare:**	    Tarifa
# * **cabin:**	Número de la cabina
# * **embarked:**	Puerto de embarque (C = Cherbourg, Q = Queenstown, S = Southampton)

# %% [markdown]
# **IMPORTAMOS LAS LIBRERÍAS Y CARGAMOS EL FICHERO**

# %%
import pandas as pd
df = pd.read_csv('titanic.csv',sep=';', index_col=0)

# %% [markdown]
# **COMPROBAMOS LOS PRIMEROS REGISTRO PARA COMPROBAR LA CARGA CORRECTA**

# %%
df.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171     7.25   NaN        S
# 2                1      0          PC 17599  712.833   C85        C
# 3                0      0  STON/O2. 3101282    7.925   NaN        S
# 4                1      0            113803     53.1  C123        S
# 5                0      0            373450     8.05   NaN        S
#
#                   birth      death
# PassengerId
# 1              1890/8/5        NaN
# 2            1874/11/18  1932/2/18
# 3             1886/9/17  1938/4/23
# 4             1877/3/10   1916/5/4
# 5             1877/4/22        NaN

# %% [markdown]
# **COMPROBAMOS LAS COLUMNAS QUE TENEMOS EN EL FICHERO**

# %%
df.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked', 'birth', 'death'],
#       dtype='object')

# %% [markdown]
# **OBTENEMOS LOS RANGOS DEL DATASET, LA CANTIDAD DE FILAS Y COLUMNAS**

# %%
df.shape
# Out:
# (906, 13)

# %%
df.info
# Out:
# <bound method DataFrame.info of              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 902                 1       1
# 903                 0       3
# 904                 1       1
# 905                 0       3
# 906                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 902                               Graham, Miss. Margaret Edith  female  19.0
# 903                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 904                                      Behr, Mr. Karl Howell    male  26.0
# 905                                        Dooley, Mr. Patrick    male  32.0
# 906                                Andersson, Mr. Anders Johan    male  39.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171     7.25   NaN        S
# 2                1      0          PC 17599  712.833   C85        C
# 3                0      0  STON/O2. 3101282    7.925   NaN        S
# 4                1      0            113803     53.1  C123        S
# 5                0      0            373450     8.05   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 902              0      0            112053       30   B42        S
# 903              1      0        W./C. 6607    23.45   NaN        S
# 904              0      0            111369       30  C148        C
# 905              0      0            370376     7.75   NaN        Q
# 906              1      5            347082   31.275   NaN        S
#
#                   birth       death
# PassengerId
# 1              1890/8/5         NaN
# 2            1874/11/18   1932/2/18
# 3             1886/9/17   1938/4/23
# 4             1877/3/10    1916/5/4
# 5             1877/4/22         NaN
# ...                 ...         ...
# 902           1893/2/23   1940/11/9
# 903           1912/9/22         NaN
# 904          1886/12/22  1919/12/13
# 905          1880/10/10         NaN
# 906           1873/7/23         NaN
#
# [906 rows x 13 columns]>

# %% [markdown]
# **OBTENEMOS LOS TIPOS PARA CONOCER LOS DATOS DEL FICHEROS**

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Name         object
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Ticket       object
# Fare         object
# Cabin        object
# Embarked     object
# birth        object
# death        object
# dtype: object

# %% [markdown]
# Podemos observar que tenemos algunos de los tipos de datos incoherentes o a priori incorrectos. Podemos ver como la edad está como Float y las fechas tanto de nacimiento como de muerte están como cadena. Veremos más adelante si convertiremos algunas de los campos a categóricos como el Sex o Embarked

# %% [markdown]
# **COMPROBAMOS LOS DUPLICADOS**
#
# Logica para [**`duplicated`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.duplicated.html):
#
# - **`keep='first'`** (default): Marca los duplicados como verdadero excepto la primera ocurrencia
# - **`keep='last'`** (default): Marca los duplicados como verdadero excepto la ultima ocurrencia
# - **`keep=False`**: Marca todos los duplicados como True.

# %%
df.duplicated()
# Out:
# PassengerId
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 902    False
# 903    False
# 904    False
# 905    False
# 906     True
# Length: 906, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 8

# %% [markdown]
# Aparentemente tenemos 8 duplicados en el fichero. Vamos a comprobar con el nombre para calcular cuantos encuentra iguales.

# %%
df['Name'].duplicated().sum()
# Out:
# 15

# %% [markdown]
# Encontramos en total a 15 nombres exactamente iguales, lo que nos indica que posiblemente tengamos 15 duplicados. Vamos a obtener la lista para poder hacer una comprobación directamente en el dataset al ser poca la cantidad de duplicados.

# %%
duplicados = df[df['Name'].duplicated(keep=False)]['Name'].tolist()
duplicados
# Out:
# ['Mallet, Master. Andre',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. Anders Johan',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Holverson, Mrs. Alexander Oskar (Mary Aline Towner)',
#  'Stewart, Mr. Albert A',
#  'Moubarek, Master. Gerios',
#  'Nye, Mrs. (Elizabeth Ramell)',
#  'Crease, Mr. Ernest James',
#  'Moutal, Mr. Rahamin Haim',
#  'Moutal, Mr. Rahamin Haim',
#  'Stewart, Mr. Albert A',
#  'Moubarek, Master. Gerios',
#  'Nye, Mrs. (Elizabeth Ramell)',
#  'Crease, Mr. Ernest James',
#  'Collyer, Miss. Marjorie "Lottie"',
#  'Pengelly, Mr. Frederick William',
#  'Hunt, Mr. George Henry',
#  'Collyer, Miss. Marjorie "Lottie"',
#  'Pengelly, Mr. Frederick William',
#  'Hunt, Mr. George Henry',
#  'Holverson, Mrs. Alexander Oskar (Mary Aline Towner)',
#  'Mallet, Master. Andre',
#  'Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)',
#  'Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)',
#  'Andersson, Mr. Anders Johan']

# %% [markdown]
# Vamos a examinar las filas duplicadas (ignorando la primera ocurrencia)

# %%
df.loc[df.duplicated(keep='first'), :]
# Out:
#              Survived  Pclass                             Name   Sex   Age  \
# PassengerId
# 16                  0       3      Andersson, Mr. Anders Johan  male  39.0
# 17                  0       3      Andersson, Mr. Anders Johan  male  39.0
# 95                  0       3         Moutal, Mr. Rahamin Haim  male   NaN
# 219                 0       1            Stewart, Mr. Albert A  male   NaN
# 222                 0       3         Crease, Mr. Ernest James  male  19.0
# 276                 0       2  Pengelly, Mr. Frederick William  male  19.0
# 277                 0       2           Hunt, Mr. George Henry  male  33.0
# 906                 0       3      Andersson, Mr. Anders Johan  male  39.0
#
#              SibSp  Parch      Ticket     Fare Cabin Embarked       birth  \
# PassengerId
# 16               1      5      347082   31.275   NaN        S   1873/7/23
# 17               1      5      347082   31.275   NaN        S   1873/7/23
# 95               0      0      374746     8.05   NaN        S    1912/5/7
# 219              0      0    PC 17605  277.208   NaN        C   1912/8/19
# 222              0      0   S.P. 3464   81.583   NaN        S  1893/12/16
# 276              0      0       28665     10.5   NaN        S   1893/7/11
# 277              0      0  SCO/W 1585   12.275   NaN        S  1879/10/17
# 906              1      5      347082   31.275   NaN        S   1873/7/23
#
#             death
# PassengerId
# 16            NaN
# 17            NaN
# 95            NaN
# 219           NaN
# 222           NaN
# 276           NaN
# 277           NaN
# 906           NaN

# %%
df.loc[df.duplicated(keep='last'), :]
# Out:
#              Survived  Pclass                             Name   Sex   Age  \
# PassengerId
# 15                  0       3      Andersson, Mr. Anders Johan  male  39.0
# 16                  0       3      Andersson, Mr. Anders Johan  male  39.0
# 17                  0       3      Andersson, Mr. Anders Johan  male  39.0
# 70                  0       1            Stewart, Mr. Albert A  male   NaN
# 73                  0       3         Crease, Mr. Ernest James  male  19.0
# 83                  0       3         Moutal, Mr. Rahamin Haim  male   NaN
# 249                 0       2  Pengelly, Mr. Frederick William  male  19.0
# 250                 0       2           Hunt, Mr. George Henry  male  33.0
#
#              SibSp  Parch      Ticket     Fare Cabin Embarked       birth  \
# PassengerId
# 15               1      5      347082   31.275   NaN        S   1873/7/23
# 16               1      5      347082   31.275   NaN        S   1873/7/23
# 17               1      5      347082   31.275   NaN        S   1873/7/23
# 70               0      0    PC 17605  277.208   NaN        C   1912/8/19
# 73               0      0   S.P. 3464   81.583   NaN        S  1893/12/16
# 83               0      0      374746     8.05   NaN        S    1912/5/7
# 249              0      0       28665     10.5   NaN        S   1893/7/11
# 250              0      0  SCO/W 1585   12.275   NaN        S  1879/10/17
#
#             death
# PassengerId
# 15            NaN
# 16            NaN
# 17            NaN
# 70            NaN
# 73            NaN
# 83            NaN
# 249           NaN
# 250           NaN

# %%
df.loc[df.duplicated(keep=False), :]
# Out:
#              Survived  Pclass                             Name   Sex   Age  \
# PassengerId
# 15                  0       3      Andersson, Mr. Anders Johan  male  39.0
# 16                  0       3      Andersson, Mr. Anders Johan  male  39.0
# 17                  0       3      Andersson, Mr. Anders Johan  male  39.0
# 70                  0       1            Stewart, Mr. Albert A  male   NaN
# 73                  0       3         Crease, Mr. Ernest James  male  19.0
# 83                  0       3         Moutal, Mr. Rahamin Haim  male   NaN
# 95                  0       3         Moutal, Mr. Rahamin Haim  male   NaN
# 219                 0       1            Stewart, Mr. Albert A  male   NaN
# 222                 0       3         Crease, Mr. Ernest James  male  19.0
# 249                 0       2  Pengelly, Mr. Frederick William  male  19.0
# 250                 0       2           Hunt, Mr. George Henry  male  33.0
# 276                 0       2  Pengelly, Mr. Frederick William  male  19.0
# 277                 0       2           Hunt, Mr. George Henry  male  33.0
# 906                 0       3      Andersson, Mr. Anders Johan  male  39.0
#
#              SibSp  Parch      Ticket     Fare Cabin Embarked       birth  \
# PassengerId
# 15               1      5      347082   31.275   NaN        S   1873/7/23
# 16               1      5      347082   31.275   NaN        S   1873/7/23
# 17               1      5      347082   31.275   NaN        S   1873/7/23
# 70               0      0    PC 17605  277.208   NaN        C   1912/8/19
# 73               0      0   S.P. 3464   81.583   NaN        S  1893/12/16
# 83               0      0      374746     8.05   NaN        S    1912/5/7
# 95               0      0      374746     8.05   NaN        S    1912/5/7
# 219              0      0    PC 17605  277.208   NaN        C   1912/8/19
# 222              0      0   S.P. 3464   81.583   NaN        S  1893/12/16
# 249              0      0       28665     10.5   NaN        S   1893/7/11
# 250              0      0  SCO/W 1585   12.275   NaN        S  1879/10/17
# 276              0      0       28665     10.5   NaN        S   1893/7/11
# 277              0      0  SCO/W 1585   12.275   NaN        S  1879/10/17
# 906              1      5      347082   31.275   NaN        S   1873/7/23
#
#             death
# PassengerId
# 15            NaN
# 16            NaN
# 17            NaN
# 70            NaN
# 73            NaN
# 83            NaN
# 95            NaN
# 219           NaN
# 222           NaN
# 249           NaN
# 250           NaN
# 276           NaN
# 277           NaN
# 906           NaN

# %% [markdown]
# Para realizar la eliminación de los duplicados utilizaremos [**`drop_duplicates`**](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop_duplicates.html)
# Por defecto tenemos el keep=False. En este caso al comprobar que son registro exactamente iguales, solo vamos a aplicar el keep='first'

# %%
df.drop_duplicates(keep='first').shape
# Out:
# (898, 13)

# %% [markdown]
# **GESTIONAR VALORES NULOS O DESCONOCIDOS**
#
# ¿Qué significa "NaN"?
# - "NaN" no es una cadena, más bien es un valor especial.
# - Significa "Not a Number" e indica un **valor ausente**.
# - **`read_csv`** detecta los valores que faltan (por defecto) al leer el archivo, y los sustituye por este valor especial.

# %%
df.isnull()
# Out:
#              Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# PassengerId
# 1               False   False  False  False  False  False  False   False
# 2               False   False  False  False  False  False  False   False
# 3               False   False  False  False  False  False  False   False
# 4               False   False  False  False  False  False  False   False
# 5               False   False  False  False  False  False  False   False
# ...               ...     ...    ...    ...    ...    ...    ...     ...
# 902             False   False  False  False  False  False  False   False
# 903             False   False  False  False   True  False  False   False
# 904             False   False  False  False  False  False  False   False
# 905             False   False  False  False  False  False  False   False
# 906             False   False  False  False  False  False  False   False
#
#               Fare  Cabin  Embarked  birth  death
# PassengerId
# 1            False   True     False  False   True
# 2            False  False     False  False  False
# 3            False   True     False  False  False
# 4            False  False     False  False  False
# 5            False   True     False  False   True
# ...            ...    ...       ...    ...    ...
# 902          False  False     False  False  False
# 903          False   True     False  False   True
# 904          False  False     False  False  False
# 905          False   True     False  False   True
# 906          False   True     False  False   True
#
# [906 rows x 13 columns]

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         181
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       699
# Embarked      2
# birth         0
# death       557
# dtype: int64

# %% [markdown]
# Con la sentencia **notnull()** tendremos lo contrario a isnull()

# %%
df.Survived.value_counts()
# Out:
# 0    557
# 1    349
# Name: Survived, dtype: int64

# %% [markdown]
# En esta caso podemos deducir que del campo "death" solo se informaron aquellos que sobrevivieron y no aquellos que fallecieron en el accidente.
# Los datos faltantes del número de la cabina parece no tan importante y respecto a la edad, gracias a que tenenos la Edad podremos calcularla justo con el año 1912 que tuvo lugar el accidente.
#
# Vamos a utilizar el método isnull() y head() para ver los registros faltantes.

# %%
df[df.Age.isnull()].head()
# Out:
#              Survived  Pclass                           Name     Sex  Age  \
# PassengerId
# 6                   0       3               Moran, Mr. James    male  NaN
# 21                  1       2   Williams, Mr. Charles Eugene    male  NaN
# 23                  1       3        Masselmani, Mrs. Fatima  female  NaN
# 30                  0       3        Emir, Mr. Farred Chehab    male  NaN
# 32                  1       3  O'Dwyer, Miss. Ellen "Nellie"  female  NaN
#
#              SibSp  Parch  Ticket    Fare Cabin Embarked       birth  \
# PassengerId
# 6                0      0  330877  84.583   NaN        Q   1912/6/11
# 21               0      0  244373      13   NaN        S   1912/8/14
# 23               0      0    2649   7.225   NaN        C  1912/12/11
# 30               0      0    2631   7.225   NaN        C  1912/11/21
# 32               0      0  330959  78.792   NaN        Q   1912/6/19
#
#                  death
# PassengerId
# 6                  NaN
# 21           1935/12/1
# 23            1937/8/3
# 30                 NaN
# 32           1937/1/25

# %% [markdown]
# Tenemos varias opciones a la hora de trabajar con los registros nulos:
#  * Si falta algún valor en una fila y la queremos eliminar por completo: **df.dropna(how='any')**
#  * Si falta algún valor en una fila (teniendo en cuenta sólo la colunma "XXXX" y "ZZZZ"), entonces que elimine esa fila: **df.dropna(subset=['XXXX', 'ZZZZ'], how='any')**
#  * Si faltan "todos" los valores en una fila (teniendo en cuenta sólo la colunma "XXXX" y "ZZZZ"), entonces queelimine esa fila: **df.dropna(subset=['XXXX', 'ZZZZ'], how='all')**
#  * Completar los valores faltantes con un valor especificado: **df['XXXX'].fillna(value='000', inplace=True)**
#  * Gestionar la carga de los datos de forma calculada
#
#  En nuestro caso vamos a calcular la edad de los datos que nos faltan:

# %%
df['birth'] = pd.to_datetime(df['birth'])

# %%
df['death'] = pd.to_datetime(df['death'])

# %%
df.dtypes
# Out:
# Survived             int64
# Pclass               int64
# Name                object
# Sex                 object
# Age                float64
# SibSp                int64
# Parch                int64
# Ticket              object
# Fare                object
# Cabin               object
# Embarked            object
# birth       datetime64[ns]
# death       datetime64[ns]
# dtype: object

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171     7.25   NaN        S
# 2                1      0          PC 17599  712.833   C85        C
# 3                0      0  STON/O2. 3101282    7.925   NaN        S
# 4                1      0            113803     53.1  C123        S
# 5                0      0            373450     8.05   NaN        S
# 6                0      0            330877   84.583   NaN        Q
# 7                0      0             17463  518.625   E46        S
# 8                3      1            349909   21.075   NaN        S
# 9                0      2            347742  111.333   NaN        S
# 10               1      0            237736  300.708   NaN        C
#
#                  birth      death
# PassengerId
# 1           1890-08-05        NaT
# 2           1874-11-18 1932-02-18
# 3           1886-09-17 1938-04-23
# 4           1877-03-10 1916-05-04
# 5           1877-04-22        NaT
# 6           1912-06-11        NaT
# 7           1858-04-09        NaT
# 8           1910-03-25        NaT
# 9           1885-06-02 1918-07-26
# 10          1898-04-28 1913-07-17

# %%
df['YearB'] = df['birth'].dt.year

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171     7.25   NaN        S
# 2                1      0          PC 17599  712.833   C85        C
# 3                0      0  STON/O2. 3101282    7.925   NaN        S
# 4                1      0            113803     53.1  C123        S
# 5                0      0            373450     8.05   NaN        S
# 6                0      0            330877   84.583   NaN        Q
# 7                0      0             17463  518.625   E46        S
# 8                3      1            349909   21.075   NaN        S
# 9                0      2            347742  111.333   NaN        S
# 10               1      0            237736  300.708   NaN        C
#
#                  birth      death  YearB
# PassengerId
# 1           1890-08-05        NaT   1890
# 2           1874-11-18 1932-02-18   1874
# 3           1886-09-17 1938-04-23   1886
# 4           1877-03-10 1916-05-04   1877
# 5           1877-04-22        NaT   1877
# 6           1912-06-11        NaT   1912
# 7           1858-04-09        NaT   1858
# 8           1910-03-25        NaT   1910
# 9           1885-06-02 1918-07-26   1885
# 10          1898-04-28 1913-07-17   1898

# %%
df['Age']= 1912-df['YearB']

# %%
df.head(10)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
#
#                                                           Name     Sex  Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male   22
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 3                                       Heikkinen, Miss. Laina  female   26
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 5                                     Allen, Mr. William Henry    male   35
# 6                                             Moran, Mr. James    male    0
# 7                                      McCarthy, Mr. Timothy J    male   54
# 8                               Palsson, Master. Gosta Leonard    male    2
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female   27
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female   14
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171     7.25   NaN        S
# 2                1      0          PC 17599  712.833   C85        C
# 3                0      0  STON/O2. 3101282    7.925   NaN        S
# 4                1      0            113803     53.1  C123        S
# 5                0      0            373450     8.05   NaN        S
# 6                0      0            330877   84.583   NaN        Q
# 7                0      0             17463  518.625   E46        S
# 8                3      1            349909   21.075   NaN        S
# 9                0      2            347742  111.333   NaN        S
# 10               1      0            237736  300.708   NaN        C
#
#                  birth      death  YearB
# PassengerId
# 1           1890-08-05        NaT   1890
# 2           1874-11-18 1932-02-18   1874
# 3           1886-09-17 1938-04-23   1886
# 4           1877-03-10 1916-05-04   1877
# 5           1877-04-22        NaT   1877
# 6           1912-06-11        NaT   1912
# 7           1858-04-09        NaT   1858
# 8           1910-03-25        NaT   1910
# 9           1885-06-02 1918-07-26   1885
# 10          1898-04-28 1913-07-17   1898

# %%
df[df.Age.isnull()].head()
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, birth, death, YearB]
# Index: []

# %% [markdown]
# **FILTRAMOS EL DATASET**
#
# Una vez exploradas las series, los registros duplicados, los valores nulos y limpiado pasamos a la fase de filtrado, agrupamiento y finalmente ordenamiento del dataset ya limpio.
# Para realizar los filtrados de los dataset utilizaremos este esquema:
# * df[df.campo > valor]
#
# Por ejemplo vamos a filtrar solo los pasaremos que son de primera clase:

# %%
df[df.Pclass==1]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 13                  1       1
# 27                  1       1
# ...               ...     ...
# 886                 0       1
# 893                 1       1
# 894                 1       1
# 902                 1       1
# 904                 1       1
#
#                                                           Name     Sex  Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 7                                      McCarthy, Mr. Timothy J    male   54
# 13                                    Bonnell, Miss. Elizabeth  female   58
# 27                                Sloper, Mr. William Thompson    male   28
# ...                                                        ...     ...  ...
# 886                                   Carlsson, Mr. Frans Olof    male   33
# 893              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56
# 894              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56
# 902                               Graham, Miss. Margaret Edith  female   19
# 904                                      Behr, Mr. Karl Howell    male   26
#
#              SibSp  Parch    Ticket     Fare        Cabin Embarked      birth  \
# PassengerId
# 2                1      0  PC 17599  712.833          C85        C 1874-11-18
# 4                1      0    113803     53.1         C123        S 1877-03-10
# 7                0      0     17463  518.625          E46        S 1858-04-09
# 13               0      0    113783    26.55         C103        S 1854-12-18
# 27               0      0    113788     35.5           A6        S 1884-11-08
# ...            ...    ...       ...      ...          ...      ...        ...
# 886              0      0       695        5  B51 B53 B55        S 1879-02-04
# 893              0      1     11767  831.583          C50        C 1856-02-16
# 894              0      1     11767  831.583          C50        C 1856-02-06
# 902              0      0    112053       30          B42        S 1893-02-23
# 904              0      0    111369       30         C148        C 1886-12-22
#
#                  death  YearB
# PassengerId
# 2           1932-02-18   1874
# 4           1916-05-04   1877
# 7                  NaT   1858
# 13          1926-04-07   1854
# 27          1933-11-07   1884
# ...                ...    ...
# 886                NaT   1879
# 893         1916-09-24   1856
# 894         1937-02-10   1856
# 902         1940-11-09   1893
# 904         1919-12-13   1886
#
# [220 rows x 14 columns]

# %% [markdown]
# Podemos filtrar por ejemplo solo los pasajeros mayores de edad y mostrar el nombre:

# %%
df[df.Age>=18].Name
# Out:
# PassengerId
# 1                                Braund, Mr. Owen Harris
# 2      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 3                                 Heikkinen, Miss. Laina
# 4           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                               Allen, Mr. William Henry
#                              ...
# 901                                Montvila, Rev. Juozas
# 902                         Graham, Miss. Margaret Edith
# 904                                Behr, Mr. Karl Howell
# 905                                  Dooley, Mr. Patrick
# 906                          Andersson, Mr. Anders Johan
# Name: Name, Length: 610, dtype: object

# %% [markdown]
# Podremos también realizar filtrados múltiple. Para ello tenemos que tener en cuenta los **operadores lógicos:**
#
# - **`and`**: Verdadero sólo si **ambos lados** del operador son Verdaderos
# - **`or`**: Verdadero si **cualquier lado** del operador es Verdadero
#
# Reglas para especificar **múltiples criterios de filtrado** en pandas:
#
# - utilizar **`&`** en lugar de **`and`**
# - usar **`|`** en lugar de **`or`**
# - añadir **paréntesis** alrededor de cada condición para especificar el orden de evaluación
#
# Por ejemplo vamos a mostrar los pasajeros de primera clase y que sean mayores de edad:

# %%
df[(df.Pclass==1) & (df.Age>=18)]
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 13                  1       1
# 27                  1       1
# ...               ...     ...
# 886                 0       1
# 893                 1       1
# 894                 1       1
# 902                 1       1
# 904                 1       1
#
#                                                           Name     Sex  Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35
# 7                                      McCarthy, Mr. Timothy J    male   54
# 13                                    Bonnell, Miss. Elizabeth  female   58
# 27                                Sloper, Mr. William Thompson    male   28
# ...                                                        ...     ...  ...
# 886                                   Carlsson, Mr. Frans Olof    male   33
# 893              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56
# 894              Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female   56
# 902                               Graham, Miss. Margaret Edith  female   19
# 904                                      Behr, Mr. Karl Howell    male   26
#
#              SibSp  Parch    Ticket     Fare        Cabin Embarked      birth  \
# PassengerId
# 2                1      0  PC 17599  712.833          C85        C 1874-11-18
# 4                1      0    113803     53.1         C123        S 1877-03-10
# 7                0      0     17463  518.625          E46        S 1858-04-09
# 13               0      0    113783    26.55         C103        S 1854-12-18
# 27               0      0    113788     35.5           A6        S 1884-11-08
# ...            ...    ...       ...      ...          ...      ...        ...
# 886              0      0       695        5  B51 B53 B55        S 1879-02-04
# 893              0      1     11767  831.583          C50        C 1856-02-16
# 894              0      1     11767  831.583          C50        C 1856-02-06
# 902              0      0    112053       30          B42        S 1893-02-23
# 904              0      0    111369       30         C148        C 1886-12-22
#
#                  death  YearB
# PassengerId
# 2           1932-02-18   1874
# 4           1916-05-04   1877
# 7                  NaT   1858
# 13          1926-04-07   1854
# 27          1933-11-07   1884
# ...                ...    ...
# 886                NaT   1879
# 893         1916-09-24   1856
# 894         1937-02-10   1856
# 902         1940-11-09   1893
# 904         1919-12-13   1886
#
# [176 rows x 14 columns]

# %% [markdown]
# **AGRUPAMIENTO DE DATOS**
#
# Para resumir la información del DataFrame, la agrupación es nuestro mejor aliado. El método .groupby() genera grupos en base a una o varias variables.
#
# Por ejemplo podríamos agrupar por tipo de clase de pasajero, donde embarcó y el sexo que tiene:

# %%
df.groupby(['Embarked','Pclass', 'Sex']).count()
# Out:
#                         Survived  Name  Age  SibSp  Parch  Ticket  Fare  \
# Embarked Pclass Sex
# C        1      female        45    45   45     45     45      45    45
#                 male          43    43   43     43     43      43    43
#          2      female         7     7    7      7      7       7     7
#                 male          11    11   11     11     11      11    11
#          3      female        23    23   23     23     23      23    23
#                 male          44    44   44     44     44      44    44
# Q        1      female         1     1    1      1      1       1     1
#                 male           1     1    1      1      1       1     1
#          2      female         2     2    2      2      2       2     2
#                 male           1     1    1      1      1       1     1
#          3      female        33    33   33     33     33      33    33
#                 male          39    39   39     39     39      39    39
# S        1      female        49    49   49     49     49      49    49
#                 male          79    79   79     79     79      79    79
#          2      female        69    69   69     69     69      69    69
#                 male          99    99   99     99     99      99    99
#          3      female        88    88   88     88     88      88    88
#                 male         270   270  270    270    270     270   270
#
#                         Cabin  birth  death  YearB
# Embarked Pclass Sex
# C        1      female     37     45     44     45
#                 male       31     43     17     43
#          2      female      1      7      7      7
#                 male        1     11      3     11
#          3      female      1     23     15     23
#                 male        0     44     11     44
# Q        1      female      1      1      1      1
#                 male        1      1      0      1
#          2      female      1      2      2      2
#                 male        0      1      0      1
#          3      female      0     33     24     33
#                 male        1     39      3     39
# S        1      female     43     49     47     49
#                 male       63     79     28     79
#          2      female      9     69     63     69
#                 male        5     99     15     99
#          3      female      5     88     33     88
#                 male        5    270     34    270

# %% [markdown]
# Con .agg() podremos añadir alguna función como sum o mean:

# %%
df.groupby(['Embarked','Pclass', 'Sex']).agg(['mean'])
# Out:
#                         Survived        Age     SibSp     Parch  \
#                             mean       mean      mean      mean
# Embarked Pclass Sex
# C        1      female  0.977778  31.688889  0.511111  0.311111
#                 male    0.395349  33.581395  0.232558  0.325581
#          2      female  1.000000  19.142857  0.714286  0.571429
#                 male    0.272727  18.909091  0.454545  0.636364
#          3      female  0.652174   9.782609  0.565217  0.608696
#                 male    0.250000  14.181818  0.250000  0.090909
# Q        1      female  1.000000  33.000000  1.000000  0.000000
#                 male    0.000000  44.000000  2.000000  0.000000
#          2      female  1.000000  15.000000  0.000000  0.000000
#                 male    0.000000  57.000000  0.000000  0.000000
#          3      female  0.727273   6.909091  0.212121  0.181818
#                 male    0.076923  10.076923  0.589744  0.128205
# S        1      female  0.959184  30.081633  0.612245  0.591837
#                 male    0.354430  33.936709  0.329114  0.253165
#          2      female  0.913043  28.956522  0.463768  0.637681
#                 male    0.151515  28.595960  0.323232  0.191919
#          3      female  0.375000  20.056818  1.238636  0.875000
#                 male    0.125926  21.555556  0.529630  0.262963
#
#                                                birth  \
#                                                 mean
# Embarked Pclass Sex
# C        1      female 1880-10-17 05:52:00.000000000
#                 male   1878-11-30 06:08:22.325581312
#          2      female 1893-03-30 13:42:51.428571648
#                 male   1893-08-08 21:49:05.454545408
#          3      female 1902-10-27 20:52:10.434782720
#                 male   1898-04-15 13:05:27.272727296
# Q        1      female 1879-10-24 00:00:00.000000000
#                 male   1868-04-19 00:00:00.000000000
#          2      female 1897-05-08 12:00:00.000000000
#                 male   1855-01-20 00:00:00.000000000
#          3      female 1905-09-05 21:05:27.272727296
#                 male   1902-06-26 03:41:32.307692288
# S        1      female 1882-05-31 01:57:33.061224448
#                 male   1878-07-24 11:14:25.822785024
#          2      female 1883-07-13 10:05:13.043478016
#                 male   1883-12-03 00:29:05.454545408
#          3      female 1892-06-10 03:00:00.000000000
#                 male   1890-12-01 15:49:20.000000000
#
#                                                death        YearB
#                                                 mean         mean
# Embarked Pclass Sex
# C        1      female 1927-06-23 18:00:00.000000000  1880.311111
#                 male   1927-09-09 21:10:35.294117632  1878.418605
#          2      female 1925-03-14 13:42:51.428571392  1892.857143
#                 male   1921-12-28 08:00:00.000000000  1893.090909
#          3      female 1926-08-22 11:12:00.000000000  1902.217391
#                 male   1927-02-22 08:43:38.181818112  1897.818182
# Q        1      female 1913-01-17 00:00:00.000000000  1879.000000
#                 male                             NaT  1868.000000
#          2      female 1927-11-05 00:00:00.000000000  1897.000000
#                 male                             NaT  1855.000000
#          3      female 1927-09-01 07:00:00.000000000  1905.090909
#                 male   1929-05-06 16:00:00.000000000  1901.923077
# S        1      female 1926-10-27 22:58:43.404255232  1881.918367
#                 male   1927-02-22 18:00:00.000000000  1878.063291
#          2      female 1926-08-14 20:11:25.714285824  1883.043478
#                 male   1930-11-16 19:12:00.000000000  1883.404040
#          3      female 1927-12-16 14:32:43.636363520  1891.943182
#                 male   1926-01-10 00:42:21.176470528  1890.444444

# %% [markdown]
# Por ejemplo si queremos mostrar la edad media de las mujeres que viajaban en cada clase.

# %%
df.groupby(['Pclass','Sex'])['Age'].mean().unstack()['female']
# Out:
# Pclass
# 1    31.268041
# 2    27.717949
# 3    15.402778
# Name: female, dtype: float64

# %% [markdown]
# **DATA BINNING**
#
# La agrupación y segmentación de datos puede ser más exhaustiva con pandas haciendo distintos grupos dentro de una misma variable. Para hacer esta agrupación se utiliza el método .cut() que permite hacer estos “cortes” de una forma muy sencilla.
#
# Por ejemplo vamos a generar tramos para el año de nacimiento que generamos en el caso de la limpieza de nulos:

# %% [markdown]
# **ORDENAR EL DATASET YA LIMPIO Y LISTO PARA MODELIZAR**

# %%
df.sort_values('Survived', ascending=True)
# Out:
#              Survived  Pclass                                Name     Sex  \
# PassengerId
# 1                   0       3             Braund, Mr. Owen Harris    male
# 529                 0       1        Walker, Mr. William Anderson    male
# 531                 0       3                   Ryan, Mr. Patrick    male
# 533                 0       3                 Pavlovic, Mr. Stefo    male
# 535                 0       3                     Vovk, Mr. Janko    male
# ...               ...     ...                                 ...     ...
# 554                 1       1             Crosby, Miss. Harriet R  female
# 553                 1       1  Frolicher, Miss. Hedwig Margaritha  female
# 220                 1       3            Moubarek, Master. Gerios    male
# 214                 1       3         Albimona, Mr. Nassef Cassem    male
# 626                 1       3         Murphy, Miss. Margaret Jane  female
#
#              Age  SibSp  Parch     Ticket     Fare Cabin Embarked      birth  \
# PassengerId
# 1             22      1      0  A/5 21171     7.25   NaN        S 1890-08-05
# 529           47      0      0      36967  340.208   D46        S 1865-04-14
# 531            0      0      0     371110    24.15   NaN        Q 1912-09-24
# 533           32      0      0     349242   78.958   NaN        S 1880-08-06
# 535           22      0      0     349252   78.958   NaN        S 1890-09-24
# ...          ...    ...    ...        ...      ...   ...      ...        ...
# 554           36      0      2  WE/P 5735       71   B22        S 1876-01-01
# 553           22      0      2      13568     49.5   B39        C 1890-04-04
# 220            0      1      0       2661  152.458   NaN        C 1912-02-04
# 214           26      0      0       2699  187.875   NaN        C 1886-07-19
# 626            0      1      0     367230     15.5   NaN        Q 1912-05-02
#
#                  death YearB  AgeN
# PassengerId
# 1                  NaT   NaN    22
# 529                NaT   NaN    47
# 531                NaT   NaN     0
# 533                NaT   NaN    32
# 535                NaT   NaN    22
# ...                ...   ...   ...
# 554         1930-08-04   NaN    36
# 553         1937-09-27   NaN    22
# 220         1933-08-21   NaN     0
# 214         1928-09-19   NaN    26
# 626         1932-12-05   NaN     0
#
# [906 rows x 15 columns]
