# %% [markdown]
# <style type="text/css">
#     ol { list-style-type: upper-alpha; }
# </style>
#
# <center> <img src=https://i.imgur.com/0TSSaqL.png width="550"> </center>
#
# <center> <h3> Module 3: Programación en Python </h3> </center>
# <center> <h4> Sesiones síncronas - 20221209 - 1/2</h4> </center>

# %% [markdown]
# ### Ejercicio 1
# Escribe cuatro programas que:
# - Asigne a una variable el valor 3 y nos muestre esa variable y su tipo.
# - Asigne a una variable el valor 14.2 y nos muestre esa variable y su tipo.
# - Asigne a una variable el valor True y nos muestre esa variable y su tipo.
# - Asigne a una variable el valor "Data Science" y nos muestre esa variable y su tipo.

# %%
# Ejercicio 1
var1 = 3
print ("var1 " + str(var1) + ", es de tipo: " + str(type(var1)))

var2 = 14.2
print ("var2 " + str(var2) + ", es de tipo: " + str(type(var2)))

var3 = True
print ("var3 " + str(var3) + ", es de tipo: " + str(type(var3)))

var4 = "Data Science"
print ("var4 " + str(var4) + ", es de tipo: " + str(type(var4)))
# Out:
# var1 3, es de tipo: <class 'int'>
# var2 14.2, es de tipo: <class 'float'>
# var3 True, es de tipo: <class 'bool'>
# var4 Data Science, es de tipo: <class 'str'>

# %% [markdown]
# ### **Ejercicio 2**
# Escribir un programa que pregunte al usuario su nombre y luego lo salude

# %%
# Ejercicio 2
name = str(input("Introduce tu nombre de usuario: "))

print("Hola " + name + "!")
# Out:
# Introduce tu nombre de usuario: Adriana
# Hola Adriana!

# %% [markdown]
# ### **Ejercicio 3**
# Escribir un programa que pregunte al usuario dos números y luego muestre:
# 1. La suma
# 2. La resta
# 3. La división
# 4. El producto

# %%
# Ejercicio 3

try:
  number1 = int(input("Introduce el número 1: "))
  number2 = int(input("Introduce el número 2: "))

  print("La suma es: " + str(number1 + number2))
  print("La resta es: " + str(number1 - number2))
  print("El producto es: " + str(number1 * number2))

  if number2 != 0:
    print("La división es: " + str(number1 / number2))

except:
  print("¡Ha habido un error al convertir el tipo de datos! ¡¡Adiós!!")
# Out:
# Introduce el número 1: 15
# Introduce el número 2: 3
# La suma es: 18
# La resta es: 12
# El producto es: 45
# La división es: 5.0

# %% [markdown]
# ### Ejercicio 4
# Escribir un programa que pregunte al usuario los valor booleanos de verdad y falso guardándolos en dos variables, y utilizarlas para mostrar por pantalla las tablas de verdad de la conjunción A∧B, mediante el uso de operadores.
#
# Pista: en el caso de los booleanos, en el sistema I/O, es necesario utilizar la función eval() para traducir los inputs de cadenas de texto a booleanos ya que el uso de bool() validaría que hemos introducido información, no lo transforma

# %%
# Ejercicio 4
try:
  vTrue = eval(input("Introduce el valor boolean True: "))
  vFalse = eval(input("Introduce el valor boolean False: "))

  print("Tabla de Verdad Conjunción A∧B")
  print(vTrue, " ∧ ", vTrue, " - ", vTrue and vTrue)
  print(vTrue, " ∧ ", vFalse, " - ", vTrue and vFalse)
  print(vFalse, " ∧ ", vTrue, " - ", vFalse and vTrue)
  print(vFalse, " ∧ ", vFalse, " - ", vFalse and vFalse)

except:
  print("¡Ha habido un error al convertir el tipo de datos! ¡¡Adiós!!")
# Out:
# Introduce el valor boolean True: True
# Introduce el valor boolean False: False
# Tabla de Verdad Conjunción A∧B
# True  ∧  True  -  True
# True  ∧  False  -  False
# False  ∧  True  -  False
# False  ∧  False  -  False

# %% [markdown]
# ### Ejercicio 5
# Escribir un programa que pregunte al usuario los valor booleanos de verdad y falso guardándolos en dos variables, y utilizarlas para mostrar por pantalla las tablas de verdad de la conjunción AvB, mediante el uso de operadores.
#
# Pista: en el caso de los booleanos, en el sistema I/O, es necesario utilizar la función eval() para traducir los inputs de cadenas de texto a booleanos ya que el uso de bool() validaría que hemos introducido información, no lo transforma

# %%
# Ejercicio 5
try:
  vTrue = eval(input("Introduce el valor boolean True: "))
  vFalse = eval(input("Introduce el valor boolean False: "))

  print("Tabla de Verdad Conjunción AvB")
  print(vTrue, " v ", vTrue, " - ", vTrue or vTrue)
  print(vTrue, " v ", vFalse, " - ", vTrue or vFalse)
  print(vFalse, " v ", vTrue, " - ", vFalse or vTrue)
  print(vFalse, " v ", vFalse, " - ", vFalse or vFalse)

except:
  print("¡Ha habido un error al convertir el tipo de datos! ¡¡Adiós!!")
# Out:
# Introduce el valor boolean True: True
# Introduce el valor boolean False: False
# Tabla de Verdad Conjunción AvB
# True  v  True  -  True
# True  v  False  -  True
# False  v  True  -  True
# False  v  False  -  False

# %% [markdown]
# ### Ejercicio 6
# Escribir un programa que asigne en variables distintas los nombres de los profesores del máster en data science de IMMUNE que habéis conocido hasta ahora y por pantalla muestre, en líneas distintas, el siguiente output:
# ```
# Asignatura: y - x
# ```
# dónde x es el nombre del profesor/a e y es la asignatura cubierta.
#
# (Pista: en caso de querer utilizar una única llamada a la función print, utilizar el carácter ``\n`` para hacer un salto de línea)

# %%
# Ejercicio 6
subject1 = "Introducción a las tecnologías de la información"
subject2 = "Programación en R"
subject3 = "Programación en Python"

teacher1 = "Elena Abril"
teacher2 = "Evaristo Abril"
teacher3 = "Luis Ridruejo"

print (subject1 + " - " + teacher1 + "\n", subject2 + " - " + teacher2 + "\n", subject3 + " - " + teacher3 + "\n")
# Out:
# Introducción a las tecnologías de la información - Elena Abril
#  Programación en R - Evaristo Abril
#  Programación en Python - Luis Ridruejo

# %% [markdown]
# ### Ejercicio 7
# Escribir un programa que solicite al usuario el radio de una esfera y muestre su área
#
# \begin{equation}
# \mathrm{A}(r) = {4} {\pi} r^{{2}}
# \end{equation}
#
# y su volúmen
# \begin{equation}
# \mathrm{V}(r) = \frac{{4}}{{3}} {\pi} r^{{3}}
# \end{equation}
#
# Bastaría con definir en una variable una estimación del numero pi.

# %%
# Ejercicio 7
# Ejemplo: un radio de 15.7 resultaría en un área de 3097.39 y un volúmen de 16209.69
import math

try:
  ratio = float(input("Introduce el radio de la esfera: "))
  area = 4 * math.pi * ratio ** 2
  volume = (4 * math.pi * ratio ** 3)/3

  print("Area = ", round(area, 2))
  print("Volúmen = ", round(volume, 2))

except:
  print("¡Ha habido un error al convertir el tipo de datos! ¡¡Adiós!!")
# Out:
# Introduce el radio de la esfera: 15.7
# Area =  3097.48
# Volúmen =  16210.17

# %% [markdown]
# ### Ejercicio 8
# Escribir un programa que solicite las coordernadas de dos puntos en el plano de los reales y calculer la distancia euclídea entre ambos.
#
# \begin{equation}
# \mathrm{d}(p1, p2) = \sqrt{\left( x_2 - x_1 \right)^{{2}} + \left( y_2 - y_1 \right)^{{2}}}
# \end{equation}

# %%
# Ejercicio 8
# Ejemplo: la distancia entre los puntos p1 = (2, 6) y p2 = (3, 6) es 1
import math

try:
  x1 = int(input("Introduce x1: "))
  y1 = int(input("Introduce y1: "))
  x2 = int(input("Introduce x2: "))
  y2 = int(input("Introduce y2: "))

  distance = math.sqrt((x2 - x1)**2 + (y2 - y1)**2)

  print("Distancia = ", round(distance, 2))

except:
  print("¡Ha habido un error al convertir el tipo de datos! ¡¡Adiós!!")
# Out:
# Introduce x1: 2
# Introduce y1: 6
# Introduce x2: 3
# Introduce y2: 6
# Distancia =  1.0

# %% [markdown]
# ### Ejercicio 9
# Escribir un programa que pida al usuario un capital inicial, una tasa de interés y un número de años. Muestra por pantalla en cuánto se habrá convertido el capital inicial transcurridos esos años si cada año se aplica la tasa de interés introducida.
#
# Pista: Recuerda que un capital de C euros a un interés del x% durante n años se convierten en
# \begin{equation}
# C \left( {1} + \frac{x}{{100}} \right)^{n}
# \end{equation}

# %%
# Ejercicio 9
# Ejemplo: 10000 euros al 4.5% de interés anual se convierte en 24117.14 al cabo de 20 años

try:
  capital = float(input("Introduce el capital inicial: "))
  rate = float(input("Introduce la tasa de interés: "))
  years = int(input("Introduce el número de años: "))

  earned_capital = capital * (1 + (rate/100)) ** years

  print("El capital ganado tras " + str(years) + " años, es " + str(round(earned_capital, 2)))

except:
  print("¡Ha habido un error al convertir el tipo de datos! ¡¡Adiós!!")
# Out:
# Introduce el capital inicial: 10000
# Introduce la tasa de interés: 4.5
# Introduce el número de años: 20
# El capital ganado tras 20 años, es 24117.14

# %% [markdown]
# ### Ejercicio 10
# Escribir un programa que solicite los valores de los coeficientes a, b y c de una ecuación de segundo grado, donde:
# \begin{equation}
# a x^{{2}} + b x + c = 0
# \end{equation}
#
# Muestre las soluciones de la ecuación.
#
# Pista: Recuerda que una ecuación de segundo grado acepta dos soluciones
# \begin{equation}
# {x_1} = \frac{-b + \sqrt{b^{{2}} - {4} a c}}{{2} a},
# {x_2} = \frac{-b - \sqrt{b^{{2}} - {4} a c}}{{2} a}
# \end{equation}

# %%
# Ejercicio 10
# Ejemplo: una ecuación de segundo grado con coeficientes a = 1, b = -5 y c = 6 tiene como soluciones x1 = 3 y x2 = 2
import math

try:
  a = int(input("Introduce el coeficiente a: "))
  b = int(input("Introduce el coeficiente b: "))
  c = int(input("Introduce el coeficiente c: "))

  x1 = (b*-1 + math.sqrt(b**2 - (4 * a * c))) / 2 * a
  x2 = (b*-1 - math.sqrt(b**2 - (4 * a * c))) / 2 * a

  print("La solución 1 de la ecuación de segundo grado x1 es " + str(x1))
  print("La solución 2 de la ecuación de segundo grado x2 es " + str(x2))

except:
  print("¡Ha habido un error al convertir el tipo de datos! ¡¡Adiós!!")
# Out:
# Introduce el coeficiente a: 1
# Introduce el coeficiente b: -5
# Introduce el coeficiente c: 6
# La solución 1 de la ecuación de segundo grado x1 es 3.0
# La solución 2 de la ecuación de segundo grado x2 es 2.0
