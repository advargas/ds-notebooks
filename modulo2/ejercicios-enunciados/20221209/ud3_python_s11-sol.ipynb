# %% [markdown]
# <style type="text/css">
#     ol { list-style-type: upper-alpha; }
# </style>
#
# <center> <img src=https://i.imgur.com/0TSSaqL.png width="550"> </center>
#
# <center> <h3> Module 3: Programación en Python </h3> </center>
# <center> <h4> Sesiones síncronas - 20221209 - 1/2</h4> </center>

# %% [markdown]
# ### Ejercicio 1
# Escribe cuatro programas que:
# - Asigne a una variable el valor 3 y nos muestre esa variable y su tipo.
# - Asigne a una variable el valor 14.2 y nos muestre esa variable y su tipo.
# - Asigne a una variable el valor True y nos muestre esa variable y su tipo.
# - Asigne a una variable el valor "Data Science" y nos muestre esa variable y su tipo.

# %%
# Ejercicio 1
a, b, c, d = 3, 14.2, True, "Data Science"
print(a, type(a))
print(b, type(b))
print(c, type(c))
print(d, type(d))
# Out:
# 3 <class 'int'>
# 14.2 <class 'float'>
# True <class 'bool'>
# Data Science <class 'str'>

# %% [markdown]
# ### **Ejercicio 2**
# Escribir un programa que pregunte al usuario su nombre y luego lo salude

# %%
# Ejercicio 2
name = str(input("¿Cómo te llamas? "))
print("Hola " + name + ", un gusto")
# Out:
# ¿Cómo te llamas? Luis
# Hola Luis, un gusto

# %% [markdown]
# ### **Ejercicio 3**
# Escribir un programa que pregunte al usuario dos números racionales y luego muestre:
# 1. La suma
# 2. La resta
# 3. La división
# 4. El producto

# %%
# Ejercicio 3
a, b = float(input("Por favor, introduzca un número racional: ")), float(input("Por favor, introduzca otro número racional: "))
print(a + b)
print(a - b)
print(a / b)
print(a * b)
# Out:
# Por favor, introduzca un número racional 3.8
# Por favor, introduzca otro número racional 17.4
# 21.2
# -13.599999999999998
# 0.21839080459770116
# 66.11999999999999

# %% [markdown]
# ### Ejercicio 4
# Escribir un programa que pregunte al usuario los valor booleanos de verdad y falso guardándolos en dos variables, y utilizarlas para mostrar por pantalla las tablas de verdad de la conjunción A∧B, mediante el uso de operadores.
#
# Pista: en el caso de los booleanos, en el sistema I/O, es necesario utilizar la función eval() para traducir los inputs de cadenas de texto a booleanos ya que el uso de bool() validaría que hemos introducido información, no lo transforma

# %%
# Ejercicio 4
v, f = eval(input("Por favor, introduzca el valor booleano de verdad: ")), eval(input("Por favor, introduzca el valor booleano de falso: "))
print("Tabla de verdad - Conjunción A∧B")
print(v, "∧", v, " - ", v and v)
print(v, "∧", f, " - ", v and f)
print(f, "∧", v, " - ", f and v)
print(f, "∧", f, " - ", f and f)
# Out:
# Por favor, introduzca el valor booleano de verdad: True
# Por favor, introduzca el valor booleano de falso: False
# Tabla de verdad - Conjunción A∧B
# True ∧ True  -  True
# True ∧ False  -  False
# False ∧ True  -  False
# False ∧ False  -  False

# %% [markdown]
# ### Ejercicio 5
# Escribir un programa que pregunte al usuario los valor booleanos de verdad y falso guardándolos en dos variables, y utilizarlas para mostrar por pantalla las tablas de verdad de la conjunción AvB, mediante el uso de operadores.
#
# Pista: en el caso de los booleanos, en el sistema I/O, es necesario utilizar la función eval() para traducir los inputs de cadenas de texto a booleanos ya que el uso de bool() validaría que hemos introducido información, no lo transforma

# %%
# Ejercicio 5
v, f = eval(input("Por favor, introduzca el valor booleano de verdad: ")), eval(input("Por favor, introduzca el valor booleano de falso: "))
print("Tabla de verdad - Disyunción AvB")
print(v, "v", v, " - ", v or v)
print(v, "v", f, " - ", v or f)
print(f, "v", v, " - ", f or v)
print(f, "v", f, " - ", f or f)
# Out:
# Por favor, introduzca el valor booleano de verdad: True
# Por favor, introduzca el valor booleano de falso: False
# Tabla de verdad - Conjunción AvB
# True v True  -  True
# True v False  -  True
# False v True  -  True
# False v False  -  False

# %% [markdown]
# ### Ejercicio 6
# Escribir un programa que asigne en variables distintas los nombres de los profesores del máster en data science de IMMUNE que habéis conocido hasta ahora y por pantalla muestre, en líneas distintas, el siguiente output:
# ```
# Asignatura: y - x
# ```
# dónde x es el nombre del profesor/a e y es la asignatura cubierta.
#
# (Pista: en caso de querer utilizar una única llamada a la función print, utilizar el carácter ``\n`` para hacer un salto de línea)

# %%
# Ejercicio 6
asig0, prof0 = "UD 0: Introducción a las TIC", "Elena Abril Medina"
asig1, prof1 = "UD 1: Fundamentos de la Programación: R", "Evaristo José Abril"
asig2, prof2 = "UD 2: Fundamentos de la Programación: Python", "Luis Ridruejo Arias"

print(
    "Asignatura: " + asig0 + " - " + prof0 + "\n"
    "Asignatura: " + asig1 + " - " + prof1 + "\n"
    "Asignatura: " + asig2 + " - " + prof2
)
# Out:
# Asignatura: UD 0: Introducción a las TIC - Elena Abril Medina
# Asignatura: UD 1: Fundamentos de la Programación: R - Evaristo José Abril
# Asignatura: UD 2: Fundamentos de la Programación: Python - Luis Ridruejo Arias

# %% [markdown]
# ### Ejercicio 7
# Escribir un programa que solicite al usuario el radio de una esfera y muestre su área
#
# \begin{equation}
# \mathrm{A}(r) = {4} {\pi} r^{{2}}
# \end{equation}
#
# y su volúmen
# \begin{equation}
# \mathrm{V}(r) = \frac{{4}}{{3}} {\pi} r^{{3}}
# \end{equation}
#
# Bastaría con definir en una variable una estimación del numero pi.

# %%
# Ejercicio 7
# Ejemplo: un radio de 15.7 resultaría en un área de 3097.39 y un volúmen de 16209.69
r = float(input("Introduzca el radio de la esfera: "))
pi = 3.1415

print("Área de la esfera: ", 4*pi*(r**2))
print("Volúmen de la esfera: ", (4/3)*pi*(r**3))
# Out:
# Introduzca el radio de la esfera: 15.7
# Área de la esfera:  3097.39334
# Volúmen de la esfera:  16209.691812666664

# %% [markdown]
# ### Ejercicio 8
# Escribir un programa que solicite las coordernadas de dos puntos en el plano de los reales y calculer la distancia euclídea entre ambos.
#
# \begin{equation}
# \mathrm{d}(p1, p2) = \sqrt{\left( x_2 - x_1 \right)^{{2}} + \left( y_2 - y_1 \right)^{{2}}}
# \end{equation}

# %%
# Ejercicio 8
# Ejemplo: la distancia entre los puntos p1 = (2, 6) y p2 = (3, 6) es 1
x1, y1 = float(input("Introduzca la coordenada x de p1: ")), float(input("Introduzca la coordenada y de p1: "))
x2, y2 = float(input("Introduzca la coordenada x de p2: ")), float(input("Introduzca la coordenada y de p2: "))

print("La distancia euclídea entre los dos puntos es: ", ((x2-x1)**2 + (y2-y1)**2)**(1/2))
# Out:
# Introduzca la coordenada x de p1: 2
# Introduzca la coordenada y de p1: 6
# Introduzca la coordenada x de p2: 3
# Introduzca la coordenada y de p2: 6
# La distancia euclídea entre los dos puntos es:  1.0

# %% [markdown]
# ### Ejercicio 9
# Escribir un programa que pida al usuario un capital inicial, una tasa de interés y un número de años. Muestra por pantalla en cuánto se habrá convertido el capital inicial transcurridos esos años si cada año se aplica la tasa de interés introducida.
#
# Pista: Recuerda que un capital de C euros a un interés del x% durante n años se convierten en
# \begin{equation}
# C \left( {1} + \frac{x}{{100}} \right)^{n}
# \end{equation}

# %%
# Ejercicio 9
# Ejemplo: 10000 euros al 4.5% de interés anual se convierte en 24117.14 al cabo de 20 años
c = float(input("¿Cuál es su capital inicial? "))
i = float(input("¿Qué tasa de interés le aplica? "))
n = float(input("¿A cuántos años? "))

print("Dispondrá de ", c * (1 + i/100)**n, " tras ", int(n), " años")
# Out:
# ¿Cuál es su capital inicial? 10000
# ¿Qué tasa de interés le aplica? 4.5
# ¿A cuántos años? 20
# Dispondrá de  24117.140248374057  tras  20  años

# %% [markdown]
# ### Ejercicio 10
# Escribir un programa que solicite los valores de los coeficientes a, b y c de una ecuación de segundo grado, donde:
# \begin{equation}
# a x^{{2}} + b x + c = 0
# \end{equation}
#
# Muestre las soluciones de la ecuación.
#
# Pista: Recuerda que una ecuación de segundo grado acepta dos soluciones
# \begin{equation}
# {x_1} = \frac{-b + \sqrt{b^{{2}} - {4} a c}}{{2} a},
# {x_2} = \frac{-b - \sqrt{b^{{2}} - {4} a c}}{{2} a}
# \end{equation}

# %%
# Ejercicio 10
# Ejemplo: una ecuación de segundo grado con coeficientes a = 1, b = -5 y c = 6 tiene como soluciones x = 3 y x = 2
a = int(input("Coeficiente a: "))
b = int(input("Coeficiente b: "))
c = int(input("Coeficiente c: "))

eq1, eq2 = -b/(2*a), (b**2 - 4*a*c)**(1/2)/(2*a)
print("Las soluciones son: ", eq1+eq2, " y ", eq1-eq2)
# Out:
# Coeficiente a: 1
# Coeficiente b: -5
# Coeficiente c: 6
# Las soluciones son:  3.0  y  2.0
