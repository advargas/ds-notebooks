# %% [markdown]
# <style type="text/css">
#     ol { list-style-type: upper-alpha; }
# </style>
#
# <center> <img src=https://i.imgur.com/0TSSaqL.png width="550"> </center>
#
# <center> <h3> Module 3: Programación en Python </h3> </center>
# <center> <h4> Sesiones síncronas - 20221209 - 2/2</h4> </center>

# %% [markdown]
# ### Ejercicio 11
# Escribir un programa que pregunte al usuario por el número de horas trabajadas y el coste por hora. Después debe mostrar por pantalla la paga que le corresponde.

# %%
# Ejercicio 11
h = float(input("¿Cuántas horas has trabajado? "))
c = float(input("¿Cuál es el coste por hora trabajada? "))

print("La paga que le corresponde es:", h * c)
# Out:
# ¿Cuántas horas has trabajado? 160
# ¿Cuál es el coste por hora trabajada? 7.60
# La paga que le corresponde es: 1216.0

# %% [markdown]
# ### Ejercicio 12
# Escribir un programa que lea un entero positivo, n, introducido por el usuario y después muestre en pantalla la suma de todos los enteros desde 1 hasta n. La suma de los n primeros enteros positivos puede ser calculada de la siguiente forma:
# \begin{equation}
# \mathrm{suma} = \frac{n \left( n + {1} \right)}{{2}}
# \end{equation}

# %%
# Ejercicio 12
n = int(input("Por favor, proporcione un número entero positivo: "))

print("La suma de los", n, "primeros enteros positivos es", (n * (n+1))/2)
# Out:
# Por favor, proporcione un número entero positivo: 5
# La suma de los 5 primeros enteros positivos es 15.0

# %% [markdown]
# ### Ejercicio 13
# Escribir un programa que pida al usuario dos números enteros y muestre por pantalla:
# ```
# La división de n entre m da un cociente c y un resto r
# ```
# Donde n y m son los números introducidos, c es el cociente de la división entera y r el resto.
#
# Pista: en Python 3.x.y el operador `/` lleva a cabo la división real, mientras que `//` lleva a cabo la entera, y `%` nos permite encontrar el módulo de un número frente a otro, o lo que es lo mismo, el resto de la división entera de un número entre otro.

# %%
# Ejercicio 13
n = int(input("Proporcione un número entero "))
m = int(input("Por favor, proporcione otro número entero "))

print("La división de", n, "entre", m, "da un cociente", n//m, "y un resto", n%m)
# Out:
# Proporcione un número entero 5
# Por favor, proporcione otro número entero 2
# La división de 5 entre 2 da un cociente 2 y un resto 1

# %% [markdown]
# ### Ejercicio 14
# Escribir un programa que pregunte el nombre del usuario en la consola y después de que el usuario lo introduzca muestre por pantalla el mensaje:
# ```
# x tiene n letras
# ```
# donde x es el nombre introducido en mayúsculas y n es el número de letras que tienen el nombre.

# %%
# Ejercicio 14
name = str(input("Introduzca su nombre: "))

print(name.upper(), "tiene", len(name), "letras")
# Out:
# Introduzca su nombre: luis
# LUIS tiene 4 letras

# %% [markdown]
# ### Ejercicio 15
# Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas. Suele hacer venta por correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de los payasos y muñecas que saldrán en cada paquete a demanda. Cada payaso pesa 112 g y cada muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último pedido y calcule el peso total del paquete que será enviado.

# %%
# Ejercicio 15
pay = int(input("¿Cuántos payasos se han vendido en el último pedido? "))
mun = int(input("¿Cuántas muñecas se han vendido en el último pedido? "))

print("El peso total del paquete es de", pay * 112 + mun * 75, "gramos")
# Out:
# ¿Cuántos payasos se han vendido en el último pedido? 14
# ¿Cuántas muñecas se han vendido en el último pedido? 36
# El peso total del paquete es de 4268 gramos

# %% [markdown]
# ### Ejercicio 16
# Una panadería vende barras de pan a 3.49€ cada una. El pan que no es el día tiene un descuento del 60%. Escribir un programa que comience leyendo el número de barras vendidas que no son del día. Después el programa debe mostrar el precio habitual de una barra de pan, el descuento que se le hace por no ser fresca y el coste final total.

# %%
# Ejercicio 16
barras = int(input("¿Cuántas barras de pan de ayer se han vendido? "))

print("El precio de una barra de pan del día es de 3.49€ sobre la que hay un descuento de", 3.49*0.6, "si no lo es, por tanto el precio total es", barras * (3.49*(1 - 60/100)))
# Out:
# ¿Cuántas barras de pan de ayer se han vendido? 35
# El precio de una barra de pan del día es de 3.49€ sobre la que hay un descuento de 2.094 si no lo es, por tanto el precio total es 48.86000000000001

# %% [markdown]
# ### Ejercicio 17
# Escribir un programa que le solicite al usuario ingresar una fecha formada por 8 números, donde los primeros cuatro representan el año, los siguientes dos el mes y los últimos dos el día (AAAAMMDD). Este dato debe guardarse en una variable con tipo int (número entero). Finalmente, mostrar al usuario la fecha con el formato "DD / MM / AAAA".

# %%
# Ejercicio 17
fecha = int(input("Por favor, ingrese una fecha con el formato AAAAMMDD "))

print(fecha%100, "/", (fecha//100)%100, "/", fecha//10000)
# Out:
# Por favor, ingrese una fecha con el formato AAAAMMDD 19741027
# 27 / 10 / 1974

# %% [markdown]
# ### Ejercicio 18
# Escribir un programa que pregunte el nombre completo del usuario en la consola y después muestre por pantalla el nombre completo del usuario tres veces:
# 1. Una con todas las letras minúsculas
# 2. Otra con todas las letras mayúsculas
# 3. Y otra solo con la primera letra del nombre y de los apellidos en mayúscula.
#
# El usuario puede introducir su nombre combinando mayúsculas y minúsculas como quiera.
#
# Pista: https://codeofgeeks.com/upper-lower-swapcase-title-capitalize-methods-in-python-strings/

# %%
# Ejercicio 18
nombre = str(input("Proporcione su nombre: "))

print(nombre.lower())
print(nombre.upper())
print(nombre.title())
# Out:
# Proporcione su nombre: luis riDRueJo AriAs
# luis ridruejo arias
# LUIS RIDRUEJO ARIAS
# Luis Ridruejo Arias

# %% [markdown]
# ### Ejercicio 19
# Escribir un programa que solicite al usuario el ingreso de una temperatura en escala Fahrenheit (debe permitir decimales) y le muestre el equivalente en grados Celsius redondeado a 2 decimales.
# \begin{equation}
# C = \frac{5}{{9}} \left(F - 32 \right)
# \end{equation}
#
# Pista: la función `round(n, d)` en Python redondea el número n a un número de dígitos d.

# %%
# Ejercicio 19
f = float(input("Por favor, introduzca la temperatura en grados Fahrenheit "))

print(f, "grados Fahrenheit equivalen a", round((5/9)*(f - 32), 2), "grados Celsius")
# Out:
# Por favor, introduzca la temperatura en grados Fahrenheit 123.64
# 123.64 grados Fahrenheit equivalen a 50.91 grados Celsius

# %% [markdown]
# ### Ejercicio 20
# Escribir un programa que pida al usuario que introduzca una frase en la consola y una vocal en minúscula, y después muestre por pantalla la misma frase pero con la vocal introducida en mayúscula.
# ```
# aprende a programar con Python → Aprende A progrAmAr con Python
# ```
# Pista: utilizar la función `replace(a, b)` que modifica el valor a por el b sobre la cadena de texto, i.e. `"patata".replace("a", "o")` resultaría en `"pototo"`

# %%
# Ejercicio 20
frase = str(input("Introduzca una frase: "))
vocal = str(input("Introduzca una vocal en minúscula: "))

print(frase.replace(vocal, vocal.upper()))
# Out:
# Introduzca una frase: la vida es domingo
# Introduzca una vocal en minúscula: o
# la vida es dOmingO
